# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-037147a7-ea7f-4ad4-993a-54397b86204b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-037147a7-ea7f-4ad4-993a-54397b86204b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# %%
df = pd.read_csv(io.BytesIO(uploaded['attendance_avg.csv'])) #reading a csv file

# %%
df.head(5)#to read first 5 elments
# Out:
#      SAP ID     ROLL ID            NAME   Avg
# 0  50002354  R211235456   Pranav Sharma  83.8
# 1  50003546  R215665563    Ranjan Kumar  63.4
# 2  50007894  R218999654  Riya Srivastav  78.0
# 3  50003156  R212256653     Aditi Tamta  83.4
# 4  50007235  R218656723   Mehak Kandpal  94.4

# %%
df.tail(5) # to print last 5 elemnts of the csv file
# Out:
#      SAP ID     ROLL ID            NAME   Avg
# 4  50007235  R218656723   Mehak Kandpal  94.4
# 5  50002324  R212544582     Sajal Suyal  69.2
# 6  50008943  R218946821  Lokesh Kapkoti  75.7
# 7  50003013  R219756894   Diwakar Bisht  69.0
# 8  50002364  R218656595  Devank Rathore  81.2

# %%
df.describe()  # to count the mean, max and min value of the given csv file
# Out:
#              SAP ID        Avg
# count  9.000000e+00   9.000000
# mean   5.000454e+07  77.566667
# std    2.682305e+03   9.468368
# min    5.000232e+07  63.400000
# 25%    5.000236e+07  69.200000
# 50%    5.000316e+07  78.000000
# 75%    5.000724e+07  83.400000
# max    5.000894e+07  94.400000

# %%
df.isna().sum()  # to show the sum of the null value
# Out:
# SAP ID     0
# ROLL ID    0
# NAME       0
# Avg        0
# dtype: int64

# %%
df.hist(figsize=(10, 8), bins=20, color='skyblue', edgecolor='black') #to define a histogram with its size,color
plt.suptitle('Distribution of Numerical Columns', fontsize=16)
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(data=df.select_dtypes(include=np.number))
plt.title('Boxplot of Numerical Columns', fontsize=16)
plt.show()
